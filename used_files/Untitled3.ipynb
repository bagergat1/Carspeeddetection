# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
inf=pd.read_excel("kayitlarx.xlsx")
inf.pop("Unnamed: 0")
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: Unnamed: 0, dtype: int64

# %%
inf.drop(0,axis=1,inplace=True)

# %%
inf.iloc[1]
# Out:
# 1      61.85
# 2      55.90
# 3     110.11
# 4     101.24
# 5      58.31
#        ...
# 59     58.31
# 60     55.90
# 61     57.01
# 62     65.19
# 63     77.62
# Name: 1, Length: 63, dtype: float64

# %%
inf
# Out:
#         1       2        3        4        5       6        7        8   \
# 0     6.00     7.0    11.00    11.00    13.00    19.0    20.00    24.00
# 1    61.85    55.9   110.11   101.24    58.31    78.1    71.06    58.31
# 2    23.69    11.8   120.23   102.48    16.62    56.2    42.13    16.62
# 3  1508.50  1508.5  6440.00  6440.00  1508.50  6440.0  3136.00  1508.50
# 4    10.00    10.0    50.00    50.00    10.00    50.0    30.00    10.00
#
#         9        10  ...       54       55       56       57       58  \
# 0    25.00    28.00  ...   133.00   135.00   135.00   141.00   141.00
# 1    57.01    80.62  ...    60.21    57.01    65.19    74.33    60.42
# 2    14.02    61.25  ...    20.42    14.02    30.38    48.66    20.83
# 3  1508.50  6440.00  ...  1508.50  1508.50  3136.00  3136.00  1508.50
# 4    10.00    50.00  ...    10.00    10.00    30.00    30.00    10.00
#
#         59      60       61       62       63
# 0   149.00   149.0   150.00   152.00   155.00
# ...

# %%
plt.subplot(3,1,1)
plt.bar([i for i in range(len(np.array(inf.iloc[1])))],np.array(inf.iloc[1]),color="red")
plt.xlabel("Araç Sayısı")
plt.ylabel("Araçların Hızı")
plt.title("Araçların Hız Grafikleri")

plt.subplot(3,1,2)
plt.bar([i for i in range(len(np.array(inf.iloc[2])))],np.array(inf.iloc[2]),color="green")
plt.xlabel("Araç Sayısı")
plt.ylabel("Sınırı Aşma Oranları (%)")
plt.title("Araçların Hız Sınırını Aşma Oranları")


plt.subplot(3,1,3)
plt.bar([i for i in range(len(np.array(inf.iloc[3])))],np.array(inf.iloc[3]),color="blue")
plt.xlabel("Araç Sayısı")
plt.ylabel("Ceza Oranları (TL)")
plt.title("Araçlara Kesilen Ceza Oranları")
plt.show()

# %%
fig, ax = plt.subplots(2,2)
ax[0,0].bar([i for i in range(len(np.array(inf.iloc[1])))],np.array(inf.iloc[1]),color="red")
plt.xlabel("Araç Sayısı")
plt.ylabel("Araçların Hızı")
plt.title("Araçların Hız Grafikleri")

ax[0,1].bar([i for i in range(len(np.array(inf.iloc[1])))],np.array(inf.iloc[1]),color="red")
plt.xlabel("Araç Sayısı")
plt.ylabel("Araçların Hızı")
plt.title("Araçların Hız Grafikleri")

ax[1,0].bar([i for i in range(len(np.array(inf.iloc[1])))],np.array(inf.iloc[1]),color="red")
plt.xlabel("Araç Sayısı")
plt.ylabel("Araçların Hızı")
plt.title("Araçların Hız Grafikleri")

ax[1,1].bar([i for i in range(len(np.array(inf.iloc[1])))],np.array(inf.iloc[1]),color="red")
plt.xlabel("Araç Sayısı")
plt.ylabel("Araçların Hızı")
plt.title("Araçların Hız Grafikleri")

fig.tight_layout(pad=5.0)
 
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 12))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"
plt.subplots_adjust(hspace=0.2, wspace=0.2)
axes[0,0].bar([i for i in range(len(np.array(inf.iloc[1])))],np.array(inf.iloc[1]),color="red")
axes[0,0].set_xlabel("Araç No")
axes[0,0].set_ylabel("Araçların Hızı")
axes[0,0].set_title("Araçların Hız Grafikleri")

axes[0,1].bar([i for i in range(len(np.array(inf.iloc[2])))],np.array(inf.iloc[2]),color="green")
axes[0,1].set_xlabel("Araç No")
axes[0,1].set_ylabel("Aşma oranı")
axes[0,1].set_title("Araçların Yasal Hız Sınırını Aşma Oranı")
fig
axes[1,0].bar([i for i in range(len(np.array(inf.iloc[3])))],np.array(inf.iloc[3]),color="brown")
axes[1,0].set_xlabel("Araç No")
axes[1,0].set_ylabel("Ceza Tutarı")
axes[1,0].set_title("Araçlara Kesilen Ceza Tutarı")

fiftyper=0
thirtyper=0
tenper=0
for i in np.array(inf.loc[4]):
    if i==50:
        fiftyper+=1
    elif i==30:
        thirtyper+=1
    elif i==10:
        tenper+=1
mylabels = ["%50 aşım sayısı","%30 aşım sayısı","%10 aşım sayısı"]
axes[1,1].pie([fiftyper,thirtyper,tenper],labels=mylabels,colors=["red","orange","blue"])
plt.savefig("Pie.pdf")

fig.show()
# Out:
# /tmp/ipykernel_5818/2839760643.py:33: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
axes[1,1].bar([i for i in range(len(np.array(inf.iloc[4])))],np.array(inf.iloc[4]),color="yellow")
axes[1,1].set_xlabel("Araç No")
axes[1,1].set_ylabel("Araçların Hızı")
axes[1,1].set_title("Araçların Hız Grafikleri")

# %%
inf
# Out:
#         1       2        3        4        5       6        7        8   \
# 0     6.00     7.0    11.00    11.00    13.00    19.0    20.00    24.00
# 1    61.85    55.9   110.11   101.24    58.31    78.1    71.06    58.31
# 2    23.69    11.8   120.23   102.48    16.62    56.2    42.13    16.62
# 3  1508.50  1508.5  6440.00  6440.00  1508.50  6440.0  3136.00  1508.50
# 4    10.00    10.0    50.00    50.00    10.00    50.0    30.00    10.00
#
#         9        10  ...       54       55       56       57       58  \
# 0    25.00    28.00  ...   133.00   135.00   135.00   141.00   141.00
# 1    57.01    80.62  ...    60.21    57.01    65.19    74.33    60.42
# 2    14.02    61.25  ...    20.42    14.02    30.38    48.66    20.83
# 3  1508.50  6440.00  ...  1508.50  1508.50  3136.00  3136.00  1508.50
# 4    10.00    50.00  ...    10.00    10.00    30.00    30.00    10.00
#
#         59      60       61       62       63
# 0   149.00   149.0   150.00   152.00   155.00
# ...

# %%
fig.savefig("SavedGraph.pdf")

# %%
# Out:
# 1     10.0
# 2     10.0
# 3     50.0
# 4     50.0
# 5     10.0
#       ...
# 59    10.0
# 60    10.0
# 61    10.0
# 62    30.0
# 63    50.0
# Name: 4, Length: 63, dtype: float64

# %%
fiftyper=0
thirtyper=0
tenper=0
for i in np.array(inf.loc[4]):
    if i==50:
        fiftyper+=1
    elif i==30:
        thirtyper+=1
    elif i==10:
        tenper+=1
mylabels = ["%50 aşım sayısı","%30 aşım sayısı","%10 aşım sayısı"]
plt.pie([fiftyper,thirtyper,tenper],labels=mylabels,colors=["red","orange","blue"])
plt.savefig("Pie.pdf")

# %%
fiftyper
# Out:
# 16

# %%
thirtyper
# Out:
# 19

# %%
inf
# Out:
#         1       2        3        4        5       6        7        8   \
# 0     6.00     7.0    11.00    11.00    13.00    19.0    20.00    24.00
# 1    61.85    55.9   110.11   101.24    58.31    78.1    71.06    58.31
# 2    23.69    11.8   120.23   102.48    16.62    56.2    42.13    16.62
# 3  1508.50  1508.5  6440.00  6440.00  1508.50  6440.0  3136.00  1508.50
# 4    10.00    10.0    50.00    50.00    10.00    50.0    30.00    10.00
#
#         9        10  ...       54       55       56       57       58  \
# 0    25.00    28.00  ...   133.00   135.00   135.00   141.00   141.00
# 1    57.01    80.62  ...    60.21    57.01    65.19    74.33    60.42
# 2    14.02    61.25  ...    20.42    14.02    30.38    48.66    20.83
# 3  1508.50  6440.00  ...  1508.50  1508.50  3136.00  3136.00  1508.50
# 4    10.00    50.00  ...    10.00    10.00    30.00    30.00    10.00
#
#         59      60       61       62       63
# 0   149.00   149.0   150.00   152.00   155.00
# ...

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 12))
fig.tight_layout() # Or equivalently,  "plt.tight_layout()"
plt.subplots_adjust(hspace=0.2, wspace=0.2)
axes[0,0].bar([i for i in range(len(np.array(inf.iloc[1])))],np.array(inf.iloc[1]),color="red")
axes[0,0].set_xlabel("Araç ID")
axes[0,0].set_ylabel("Araçların Hızı")
axes[0,0].set_title("Araçların Hız Grafikleri")

axes[0,1].bar([i for i in range(len(np.array(inf.iloc[2])))],np.array(inf.iloc[2]),color="green")
axes[0,1].set_xlabel("Araç ID")
axes[0,1].set_ylabel("Araçların Hızı")
axes[0,1].set_title("Araçların Hız Grafikleri")

axes[1,0].bar([i for i in range(len(np.array(inf.iloc[3])))],np.array(inf.iloc[3]),color="blue")
axes[1,0].set_xlabel("Araç ID")
axes[1,0].set_ylabel("Araçların Hızı")
axes[1,0].set_title("Araçların Hız Grafikleri")

axes[1,1].bar([i for i in range(len(np.array(inf.iloc[4])))],np.array(inf.iloc[4]),color="yellow")
axes[1,1].set_xlabel("Araç ID")
axes[1,1].set_ylabel("Araçların Hızı")
axes[1,1].set_title("Araçların Hız Grafikleri")
